# %%
import torch

# %%
PATH = "../data/_processed/"
X_trip_test = torch.load(PATH + "triplets_test.pt")
y_trip_test = torch.load(PATH + "y_train.pt")

# %%
X_trip_test[0]
# Out:
# (tensor([[0.0000e+00, 0.0000e+00, 1.4268e+05],
#          [0.0000e+00, 1.0000e+00, 7.0000e+01],
#          [0.0000e+00, 2.0000e+00, 1.0000e+00],
#          ...,
#          [2.8680e+03, 8.0000e+00, 4.3000e+01],
#          [2.8680e+03, 1.4000e+01, 2.2000e+01],
#          [2.8680e+03, 3.0000e+01, 3.7600e+01]]),
#  142675)

# %%
X_trip_test[0][0].size()
# Out:
# torch.Size([767, 3])

# %%
y_trip_test[0]
# Out:
# tensor(0.)

# %%
y_trip_test.size()
# Out:
# torch.Size([400])
